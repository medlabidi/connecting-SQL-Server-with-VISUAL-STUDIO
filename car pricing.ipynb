# %% [markdown]
#  ## pyodbc & pandas install

# %%
# %pip install pyodbc
# %pip install pandas

# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import pyodbc

# %% [markdown]
# ## build a connection

# %%
conn= pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-9C2II2A;'
                      'Database=CarTest;'
                      'Trusted_Connection=yes;')

# %%
cursor=conn.cursor()
cursor.execute('select * from [dbo].[CarData]')

# %% [markdown]
# ## showing datasets

# %%
rows= cursor.fetchall()
for i in rows:
    print(i)
# Out:
# Hero Passion X pro
# xcent
# verna
# ertiga
# jazz
# Honda CB Hornet 160R
# Honda CBR 150
# KTM 390 Duke
# sx4
# vitara brezza
# etios g
# verna
# city
# Hero Super Splendor
# ciaz
# Hero Glamour
# ritz
# Activa 3g
# Hero Extreme
# swift
# verna
# brio
# ciaz
# Honda CB twister
# etios liva
# ritz
# brio
# Yamaha FZ  v 2.0
# corolla altis
# xcent
# xcent
# jazz
# UM Renegade Mojave
# swift
# Yamaha FZ  v 2.0
# city
# Royal Enfield Classic 350
# fortuner
# etios liva
# city
# verna
# etios liva
# corolla altis
# Royal Enfield Bullet 350
# etios cross
# sx4
# Bajaj Avenger 150 street
# camry
# corolla altis
# fortuner
# ritz
# i20
# dzire
# etios cross
# Royal Enfield Classic 350
# fortuner
# sx4
# xcent
# Royal Enfield Thunder 350
# Royal Enfield Thunder 350
# Bajaj Pulsar 150
# ciaz
# fortuner
# Royal Enfield Thunder 500
# ciaz
# jazz
# jazz
# verna
# city
# Hero Extreme
# etios cross
# Yamaha FZ  v 2.0
# innova
# i20
# Honda Activa 4G
# etios gd
# grand i10
# Yamaha FZ 16
# ...
